# %%
#W3A2
a, b = map(int, input().split())
a = a^b
b = a^b
a = a^b
print(a, " ", b)
# Out:
# 4   3

# %%
#w3A3
n = int(input())
if ( n > 0 and (n&(n-1))==0):
  print("n là lũy thừa của 2")
else:
     print("n không phải lũy thừa của 2")
# Out:
# n không phải lũy thừa của 2

# %%
#w3A4
m,n = map(float,input().split())
print(m//n)
# Out:
# 2.0

# %%
#W3A5
m,n = map(float,input().split())
print(m//n + 1)
# Out:
# 1.0

# %%
#W3A6
x = int(input())
if x%2==0: print ("Even")
else: print ("Odd")
# Out:
# Even

# %%
#W3A7
a,b = map(int, input().split())
if (a < 0 and b < 0):print("Yes")
else: print ("No")
# Out:
# No

# %%
#W3A8
a, b = map(str, input().split())
if (len(a) > len(b)): print("True")
else: print("False")
# Out:
# True

# %%
#W3A9
a,b,c = map(int,input().split())
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A10
a,b,c,d = map(int, input().split())
print(max(a,b,c,d))
# Out:
# 4

# %%
#W3A11
a,b,c = map(int,input().split())
if a + b > c and a + c > b and b + c > a:
    if a == b == c :  print("Tam giác đều")
    elif a==b or b == c or a == c: print("Tam giác cân")
    else: print("Tam giác thường")
else:
    print("Không phải tam giác")
# Out:
# Không phải tam giác

# %%
#W3A12
n = int(input())
if n%4== 0 and n%100!=0: print("Yes")
elif n%400 == 0: print("Yes")
else: print("No")
# Out:
# No

# %%
#W3A14
a, b =map(int,input().split())
if a == 0:
    if b == 0: print("Vô số nghiệm")
    else:print("Vô nghiệm")
else:
    print(f"{-b/a:.2f}")
# Out:
# Vô số nghiệm

# %%
#W3A15
x = float(input())
if x >= 8: print("Giỏi")
elif 6.5 <= x < 8: print("Khá")
elif 5.0 <= x < 6.5: print("Trung bình")
else: print("Yếu")
# Out:
# Khá

# %%
#W3A16
x= float(input())
if x > 0 and x !=  int(x): 
    xuong = int(x)
    lenn =  int(x) + 1
    if abs(x - int(x)) >= 0.5:
        gn = int(x) + 1
    else:
        gn = int(x)

elif x < 0 and x!=  int(x): 
    xuong= int(x) -1
    lenn =  int(x)
    if abs(x - int(x)) >= 0.5:
        gn = int(x) - 1
    else:
        gn = int(x)
    
else: 
    xuong = int(x)
    lenn =  int(x)
    gn = int(x)

print(lenn,xuong,gn)
# Out:
# -8 -9 -8

# %%
#W3A17
a, b, c, d =map(int,input().split())
if b % a == 0 and c % b == 0 and d % c == 0:
    r = b / a 
    if b*r == c and c*r == d:
        print("4 số là cấp số nhân với công bội ", r)
    else: print(" Không phải cấp số nhân ")
else: print(" Không phải cấp số nhân ")
# Out:
#  Không phải cấp số nhân
